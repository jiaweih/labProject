# %% [markdown]
# #### Following is what we originally did by comparing PRISM (1981-2010) with Livneh (1950-2011), which was considered to make no sense:

# %%
from mpl_toolkits.basemap import Basemap, cm
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

vars = {'Prec', 'Tmax', 'Tmin'}
#vars = {'Tmax'}
idx = 0
for var in vars:
    #ftemplate = '/raid3/jiawei/homero/prism/livneh/data.' + var +'.diff.nc'
    ftemplate = '/raid3/jiawei/homero/data/prism/1950.2011/anomaly/data.' + var + '.diff.nc'
    fig = plt.figure(figsize=(10,10))
    #grid = gridspec.GridSpec(1, 3, height_ratios=[1,1,1,1,0.05], wspace=0.05, hspace=0.05)
    #ax = fig.add_subplot(grid[idx])
    ax = fig.add_subplot(111)
    nc = Dataset(ftemplate, 'r')
    data = nc.variables[var][:]
    lon = nc.variables['lon'][:]
    lat = nc.variables['lat'][:]
    nc.close()
    m = Basemap(projection='merc',llcrnrlat=25.25,urcrnrlat=49.25,\
        llcrnrlon=-124.75,urcrnrlon=-67.25,lat_ts=30,resolution='c')
    m.drawcoastlines(linewidth=0.25)
    xi, yi = m(*np.meshgrid(lon, lat))
    cs = m.contourf(xi,yi,data,levels = np.linspace(-4.5,4.5,10),cmap=plt.cm.seismic,extend='both') #extend both end of colorbar
    ax.text(0.97, 0.97, var, verticalalignment='top', horizontalalignment='right',
                transform=ax.transAxes, color='black', fontsize=16)
    ax.text(0.5, 0.91, "PRISM-Livneh", verticalalignment='top', horizontalalignment='center',
                transform=ax.transAxes, color='black', fontsize=16)
    idx += 1
    pos = ax.get_position()
    l, b, w, h = pos.bounds
    #cax = plt.axes([l,b,w,h])
    #cax = plt.axes([l, b, w, 0.01])
   # cax = plt.axes([l, b, w, h])
    #cax = plt.axes([l-.2, b-0.03, w, 0.01])
    #cbar = plt.colorbar(cax=cax,orientation='horizontal')
    cbar = m.colorbar(cs,location='bottom',pad="5%")
    cbar.ax.tick_params(labelsize=10)
    if var == 'Prec':
        cbar.set_label( ' (mm/day)',fontsize = 10)
    else:
        cbar.set_label('($^\circ$C)',fontsize = 10)
    plt.show()
    fig.savefig('PRISM_anomaly_' + var +'.png')
    #fig.savefig('PRISM_anomaly.png')

# %% [markdown]
# #### Following is what I recently did by comparing PRISM (1981-2010) with Livneh (1981-2010), which was considered to make some sense:

# %%
from mpl_toolkits.basemap import Basemap, cm
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

vars = {'Prec', 'Tmax', 'Tmin'}
#vars = {'Tmax'}
idx = 0
for var in vars:
    #ftemplate = '/raid3/jiawei/homero/prism/livneh/data.' + var +'.diff.nc'
    ftemplate = '/raid3/jiawei/homero/data/prism/1981.2010/anomaly/data.' + var + '.diff.nc'
    fig = plt.figure(figsize=(10,10))
    #grid = gridspec.GridSpec(1, 3, height_ratios=[1,1,1,1,0.05], wspace=0.05, hspace=0.05)
    #ax = fig.add_subplot(grid[idx])
    ax = fig.add_subplot(111)
    nc = Dataset(ftemplate, 'r')
    data = nc.variables[var][:]
    lon = nc.variables['lon'][:]
    lat = nc.variables['lat'][:]
    nc.close()
    m = Basemap(projection='merc',llcrnrlat=25.25,urcrnrlat=49.25,\
        llcrnrlon=-124.75,urcrnrlon=-67.25,lat_ts=30,resolution='c')
    m.drawcoastlines(linewidth=0.25)
    xi, yi = m(*np.meshgrid(lon, lat))
    cs = m.contourf(xi,yi,data,levels = np.linspace(-4.5,4.5,10),cmap=plt.cm.seismic,extend='both') #extend both end of colorbar
    ax.text(0.97, 0.97, var, verticalalignment='top', horizontalalignment='right',
                transform=ax.transAxes, color='black', fontsize=16)
    ax.text(0.5, 0.91, "PRISM(1981~2010)-Livneh", verticalalignment='top', horizontalalignment='center',
                transform=ax.transAxes, color='black', fontsize=16)
    idx += 1
    pos = ax.get_position()
    l, b, w, h = pos.bounds
    #cax = plt.axes([l,b,w,h])
    #cax = plt.axes([l, b, w, 0.01])
   # cax = plt.axes([l, b, w, h])
    #cax = plt.axes([l-.2, b-0.03, w, 0.01])
    #cbar = plt.colorbar(cax=cax,orientation='horizontal')
    cbar = m.colorbar(cs,location='bottom',pad="5%")
    cbar.ax.tick_params(labelsize=10)
    if var == 'Prec':
        cbar.set_label( ' (mm/day)',fontsize = 10)
    else:
        cbar.set_label('($^\circ$C)',fontsize = 10)
    plt.show()
    fig.savefig('PRISM_anomaly_1981_2010_' + var +'.png')
    #fig.savefig('PRISM_anomaly.png')

# %% [markdown]
# #### Following is what I recently did by comparing PRISM (1971-2000) with Livneh (1971-2000), which I don't know whether makes sense:

# %%
from mpl_toolkits.basemap import Basemap, cm
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

vars = {'Prec', 'Tmax', 'Tmin'}
#vars = {'Tmax'}
idx = 0
for var in vars:
    #ftemplate = '/raid3/jiawei/homero/prism/livneh/data.' + var +'.diff.nc'
    ftemplate = '/raid3/jiawei/homero/data/prism/1971.2000/anomaly/data.' + var + '.diff.nc'
    fig = plt.figure(figsize=(10,10))
    #grid = gridspec.GridSpec(1, 3, height_ratios=[1,1,1,1,0.05], wspace=0.05, hspace=0.05)
    #ax = fig.add_subplot(grid[idx])
    ax = fig.add_subplot(111)
    nc = Dataset(ftemplate, 'r')
    data = nc.variables[var][:]
    lon = nc.variables['lon'][:]
    lat = nc.variables['lat'][:]
    nc.close()
    m = Basemap(projection='merc',llcrnrlat=25.25,urcrnrlat=49.25,\
        llcrnrlon=-124.75,urcrnrlon=-67.25,lat_ts=30,resolution='c')
    m.drawcoastlines(linewidth=0.25)
    xi, yi = m(*np.meshgrid(lon, lat))
    cs = m.contourf(xi,yi,data,levels = np.linspace(-4.5,4.5,10),cmap=plt.cm.seismic,extend='both') #extend both end of colorbar
    ax.text(0.97, 0.97, var, verticalalignment='top', horizontalalignment='right',
                transform=ax.transAxes, color='black', fontsize=16)
    ax.text(0.5, 0.91, "PRISM(1971~2000)-Livneh", verticalalignment='top', horizontalalignment='center',
                transform=ax.transAxes, color='black', fontsize=16)
    idx += 1
    pos = ax.get_position()
    l, b, w, h = pos.bounds
    #cax = plt.axes([l,b,w,h])
    #cax = plt.axes([l, b, w, 0.01])
   # cax = plt.axes([l, b, w, h])
    #cax = plt.axes([l-.2, b-0.03, w, 0.01])
    #cbar = plt.colorbar(cax=cax,orientation='horizontal')
    cbar = m.colorbar(cs,location='bottom',pad="5%")
    cbar.ax.tick_params(labelsize=10)
    if var == 'Prec':
        cbar.set_label( ' (mm/day)',fontsize = 10)
    else:
        cbar.set_label('($^\circ$C)',fontsize = 10)
    plt.show()
    fig.savefig('PRISM_anomaly_1971_2000_' + var +'.png')
    #fig.savefig('PRISM_anomaly.png')
