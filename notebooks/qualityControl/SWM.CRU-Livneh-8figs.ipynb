# %% [markdown]
# #Plotting SWM/CRU-Livneh sesasonaly, for two periods#
# #1915-1950 and 1951-2011#

# %%
from mpl_toolkits.basemap import Basemap, cm
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
#pylab inline --no-import-all

vars = {'Prec', 'Tmax', 'Tmin'}
seasons = ['Spring','Summer', 'Autumn', 'Winter']
store_dir = '/raid3/jiawei/homero/plots/'
methods = ['swm','cru']
periods = ['pre1950','pos1950']

for method in methods: 
    source_dir = '/raid3/jiawei/homero/data/'+method+'/'    
    if method == 'swm':
        mName = 'SWM'
    else:
        mName = 'CRU'

    for var in vars:
        # Create figure   
        fig = plt.figure(figsize=(20,20))
        # Layout panels in figure
        grid = gridspec.GridSpec(4, 2, height_ratios=[1,1,1,1,0.05], wspace=0.05, hspace=0.05)
        
        for i in [0,1]:
            #define the template for the filename
            period = periods[i]
            ftemplate = source_dir+method+'.'+period+'.{}.nc' #######################
            if period == 'pre1950':
                pName = '1915-1950'
                shift = 0
            else:
                pName = '1951-2011'
                shift = 4
            idx = 0
            for season in seasons:
        #        plt.subplot(index)
                # open panel
                ax = fig.add_subplot(grid[idx+shift])
                # read netcdf file
                nc = Dataset(ftemplate.format(season), 'r')
                datavar = nc.variables[var]
                data=datavar[0][:]
                lon=nc.variables['lon'][:]
                lat=nc.variables['lat'][:]
                nc.close()
                # plot
                m = Basemap(projection='merc',llcrnrlat=25.25,urcrnrlat=49.25,\
                llcrnrlon=-124.75,urcrnrlon=-67.25,lat_ts=30,resolution='c')
                m.drawcoastlines(linewidth=0.25)
                xi, yi = m(*np.meshgrid(lon, lat))
                cs = m.contourf(xi,yi,data,levels = np.linspace(-4.5,4.5,10),cmap=plt.cm.seismic, extend="both")
                #plt.title(season, fontsize=15)
                # add text
                ax.text(0.10, 0.97, seasons[idx], verticalalignment='top', horizontalalignment='left',
                        transform=ax.transAxes, color='black', fontsize=16)
                ax.text(0.97, 0.97, var, verticalalignment='top', horizontalalignment='right',
                        transform=ax.transAxes, color='black', fontsize=16)
                ax.text(0.5, 0.97, pName, verticalalignment='top', horizontalalignment='center',
                        transform=ax.transAxes, color='black', fontsize=16) 
                ax.text(0.5, 0.91, mName+"-Livneh", verticalalignment='top', horizontalalignment='center',
                        transform=ax.transAxes, color='black', fontsize=16)
                idx += 1    
        # get axes bounds.
        pos = ax.get_position()
        l, b, w, h = pos.bounds 
        # create axes instance for colorbar on bottom.
        cax = plt.axes([l-.2, b-0.03, w, 0.01])
        # draw colorbar on bottom.
        cbar = plt.colorbar(cax=cax,orientation='horizontal')
        if var == 'Prec':
            cbar.set_label(' (mm/day)')
        else:
            cbar.set_label(' (C)')
        plt.show() 
                
        
        fig.savefig(store_dir+'figures/'+mName+'_anomaly_'+var+'.png')

# %%
from mpl_toolkits.basemap import Basemap, cm
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
#pylab inline --no-import-all

vars = {'Prec', 'Tmax', 'Tmin'}
seasons = ['Spring','Summer', 'Autumn', 'Winter']
store_dir = '/raid3/jiawei/homero/plots/'
methods = ['swm','cru']
periods = ['pre1950','pos1950']

for method in methods: 
    source_dir = '/raid3/jiawei/homero/data/'+method+'/'    
    if method == 'swm':
        mName = 'SWM'
    else:
        mName = 'CRU'

    for var in vars:
        # Create figure   
        fig = plt.figure(figsize=(20,20))
        # Layout panels in figure
        grid = gridspec.GridSpec(4, 2, height_ratios=[1,1,1,1,0.05], wspace=0.05, hspace=0.05)
        
        for i in [0,1]:
            #define the template for the filename
            period = periods[i]
            ftemplate = source_dir+method+'.'+period+'.{}.nc' #######################
            if period == 'pre1950':
                pName = '1915-1950'
                shift = 0
            else:
                pName = '1951-2011'
                shift = 4
            idx = 0
            for season in seasons:
        #        plt.subplot(index)
                # open panel
                ax = fig.add_subplot(grid[idx+shift])
                # read netcdf file
                nc = Dataset(ftemplate.format(season), 'r')
                datavar = nc.variables[var]
                data=datavar[0][:]
                lon=nc.variables['lon'][:]
                lat=nc.variables['lat'][:]
                nc.close()
                # plot
                m = Basemap(projection='merc',llcrnrlat=25.25,urcrnrlat=52.25,\
                llcrnrlon=-124.75,urcrnrlon=-67.25,lat_ts=30,resolution='c')
                m.drawcoastlines(linewidth=0.25)
                xi, yi = m(*np.meshgrid(lon, lat))
                cs = m.contourf(xi,yi,data,levels = np.linspace(-4.5,4.5,10),cmap=plt.cm.seismic, extend="both")
                #plt.title(season, fontsize=15)
                # add text
                ax.text(0.10, 0.97, seasons[idx], verticalalignment='top', horizontalalignment='left',
                        transform=ax.transAxes, color='black', fontsize=16)
                ax.text(0.97, 0.97, var, verticalalignment='top', horizontalalignment='right',
                        transform=ax.transAxes, color='black', fontsize=16)
                ax.text(0.5, 0.97, pName, verticalalignment='top', horizontalalignment='center',
                        transform=ax.transAxes, color='black', fontsize=16) 
                ax.text(0.5, 0.91, mName+"-Livneh", verticalalignment='top', horizontalalignment='center',
                        transform=ax.transAxes, color='black', fontsize=16)
                idx += 1    
        # get axes bounds.
        pos = ax.get_position()
        l, b, w, h = pos.bounds 
        # create axes instance for colorbar on bottom.
        cax = plt.axes([l-.2, b-0.03, w, 0.01])
        # draw colorbar on bottom.
        cbar = plt.colorbar(cax=cax,orientation='horizontal')
        if var == 'Prec':
            cbar.set_label(' (mm/day)')
        else:
            cbar.set_label(' (C)')
        plt.show() 
                
        
        fig.savefig(store_dir+'figures/'+mName+'_anomaly_'+var+'.png')

# %%
# Out:
# [0, 1]

# %%
periods = ['a','b']
           
for i in a:
    print i
    print periods[i]
# Out:
# 0
# a
# 1
# b

# %%
print periods
# Out:
# set(['pos1950', 'pre1950'])
